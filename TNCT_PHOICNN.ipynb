# %% [markdown]
# <a href="https://colab.research.google.com/github/SeaLeeDawng1one/CT-Phoi/blob/main/TNCT_PHOICNN_update.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2
from sklearn.utils import shuffle
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, AveragePooling2D, Flatten, Dense
from tensorflow.keras.optimizers import Adam
from google.colab import drive
import os

# 1. Mount Google Drive và load dữ liệu
drive.mount('/content/gdrive', force_remount=True)
data_dir = "/content/gdrive/My Drive/saved_data"

X_train = np.load(os.path.join(data_dir, "train_images.npy"))
y_train = np.load(os.path.join(data_dir, "train_labels.npy"))
X_test  = np.load(os.path.join(data_dir, "valid_images.npy"))
y_test  = np.load(os.path.join(data_dir, "valid_labels.npy"))

# 2. Kiểm tra shape và chuyển định dạng nếu cần (channels_first -> channels_last)
print("Before transpose:", X_train.shape)
if X_train.ndim == 4 and X_train.shape[1] == 3:
    X_train = X_train.transpose(0, 2, 3, 1)
    X_test  = X_test.transpose(0, 2, 3, 1)
print("After transpose: ", X_train.shape)
print("y_train unique labels:", np.unique(y_train))

# 3. Hiển thị ảnh gốc mẫu
plt.figure(figsize=(4, 4))
plt.imshow(X_train[0].astype(np.uint8))
plt.title("Ảnh Gốc")
plt.axis("off")
plt.show()

# 4. Tiền xử lý ảnh: Resize, Blur, Brightness
def preprocess_image(img):
    img_resized = cv2.resize(img, (224, 224))
    img_blurred = cv2.GaussianBlur(img_resized, (5, 5), 0)
    hsv = cv2.cvtColor(img_blurred, cv2.COLOR_RGB2HSV)
    hsv[:, :, 2] = np.clip(hsv[:, :, 2] * 1.2, 0, 255)
    img_bright = cv2.cvtColor(hsv, cv2.COLOR_HSV2RGB)
    return img_bright

# 5. Áp dụng tiền xử lý ảnh
X_train = np.array([preprocess_image(img) for img in X_train])
X_test = np.array([preprocess_image(img) for img in X_test])

# 6. Hiển thị ảnh mẫu sau tiền xử lý
plt.figure(figsize=(4, 4))
plt.imshow(X_train[0].astype(np.uint8))
plt.title("Ảnh Sau Tiền Xử Lý")
plt.axis("off")
plt.show()

# 7. Shuffle và chuẩn hóa dữ liệu
X_train, y_train = shuffle(X_train, y_train, random_state=1080)
X_test,  y_test  = shuffle(X_test,  y_test,  random_state=1080)

X_train = X_train.astype('float32') / 255.0
X_test  = X_test.astype('float32') / 255.0

# 8. Xây dựng mô hình CNN
model = Sequential([
    Conv2D(32, (3,3), activation='relu', input_shape=(224,224,3)),
    MaxPooling2D((3,3)),
    Conv2D(64, (5,5), activation='relu'),
    AveragePooling2D((3,3)),
    Flatten(),
    Dense(128, activation='relu'),
    Dense(len(np.unique(y_train)), activation='softmax')
])

model.compile(
    optimizer=Adam(learning_rate=1e-4),
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
model.summary()

# 9. Huấn luyện mô hình
history = model.fit(
    X_train, y_train,
    epochs=60,
    batch_size=32,
    validation_split=0.1,
    verbose=1
)

# 10. Vẽ biểu đồ Training và Validation Accuracy
plt.figure(figsize=(10, 5))
plt.plot(history.history['accuracy'], label='Training accuracy', color='red')
plt.plot(history.history['val_accuracy'], label='Validation accuracy', color='blue')
plt.title('Training and validation accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()

# 11. Đánh giá trên tập test
test_loss, test_acc = model.evaluate(X_test, y_test, verbose=1)
print(f"Test loss: {test_loss:.4f}")
print(f"Test accuracy: {test_acc:.4f}")

# 12. Dự đoán và vẽ Confusion Matrix
y_pred_probs = model.predict(X_test)
y_pred = np.argmax(y_pred_probs, axis=1)

classes = np.unique(y_test)
label_names = ['lung_aca','lung_n','lung_scc','unknown']  # Tuỳ chỉnh theo nhãn thực tế

cm = confusion_matrix(y_test, y_pred, labels=classes)
disp = ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=label_names)
disp.plot(cmap='Blues', xticks_rotation=45)
plt.title("Confusion Matrix")
plt.tight_layout()
plt.show()
# Out:
# Mounted at /content/gdrive
# Before transpose: (613, 3, 224, 224)
# After transpose:  (613, 224, 224, 3)
# y_train unique labels: [0 1 2 3]
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/convolutional/base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 222, 222, 32)   │           896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 74, 74, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 70, 70, 64)     │        51,264 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ average_pooling2d               │ (None, 23, 23, 64)     │             0 │
# │ (AveragePooling2D)              │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 33856)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │     4,333,696 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,386,372 (16.73 MB)
#  Trainable params: 4,386,372 (16.73 MB)
#  Non-trainable params: 0 (0.00 B)
# Epoch 1/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 11s 330ms/step - accuracy: 0.2364 - loss: 1.3813 - val_accuracy: 0.3548 - val_loss: 1.3627
# Epoch 2/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.4403 - loss: 1.3226 - val_accuracy: 0.3871 - val_loss: 1.3030
# Epoch 3/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5235 - loss: 1.2007 - val_accuracy: 0.4032 - val_loss: 1.3231
# Epoch 4/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5010 - loss: 1.1094 - val_accuracy: 0.3871 - val_loss: 1.3262
# Epoch 5/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.5052 - loss: 1.0872 - val_accuracy: 0.3871 - val_loss: 1.2551
# Epoch 6/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.5194 - loss: 1.0601 - val_accuracy: 0.3871 - val_loss: 1.1972
# Epoch 7/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.4990 - loss: 1.0220 - val_accuracy: 0.4032 - val_loss: 1.1758
# Epoch 8/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5171 - loss: 1.0138 - val_accuracy: 0.3871 - val_loss: 1.1276
# Epoch 9/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5171 - loss: 0.9809 - val_accuracy: 0.4032 - val_loss: 1.0980
# Epoch 10/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.5280 - loss: 0.9404 - val_accuracy: 0.4032 - val_loss: 1.0803
# Epoch 11/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.5568 - loss: 0.9334 - val_accuracy: 0.5161 - val_loss: 1.0508
# Epoch 12/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.5414 - loss: 0.9248 - val_accuracy: 0.5323 - val_loss: 1.0274
# Epoch 13/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5545 - loss: 0.9409 - val_accuracy: 0.4194 - val_loss: 1.0467
# Epoch 14/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.5657 - loss: 0.8801 - val_accuracy: 0.5323 - val_loss: 1.0190
# Epoch 15/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6280 - loss: 0.8734 - val_accuracy: 0.5645 - val_loss: 0.9962
# Epoch 16/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.5575 - loss: 0.8710 - val_accuracy: 0.5484 - val_loss: 0.9934
# Epoch 17/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.6430 - loss: 0.8250 - val_accuracy: 0.5323 - val_loss: 0.9925
# Epoch 18/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6117 - loss: 0.8130 - val_accuracy: 0.5645 - val_loss: 0.9901
# Epoch 19/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.6526 - loss: 0.7922 - val_accuracy: 0.5161 - val_loss: 0.9860
# Epoch 20/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.6648 - loss: 0.7931 - val_accuracy: 0.5806 - val_loss: 0.9452
# Epoch 21/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.6806 - loss: 0.7376 - val_accuracy: 0.6290 - val_loss: 0.9662
# Epoch 22/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.6940 - loss: 0.7420 - val_accuracy: 0.5806 - val_loss: 0.9826
# Epoch 23/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.6497 - loss: 0.7335 - val_accuracy: 0.5484 - val_loss: 1.0164
# Epoch 24/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 41ms/step - accuracy: 0.7054 - loss: 0.7169 - val_accuracy: 0.5645 - val_loss: 0.9582
# Epoch 25/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7127 - loss: 0.6670 - val_accuracy: 0.5323 - val_loss: 1.0221
# Epoch 26/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7201 - loss: 0.6656 - val_accuracy: 0.5806 - val_loss: 0.9777
# Epoch 27/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7199 - loss: 0.6516 - val_accuracy: 0.6129 - val_loss: 1.0187
# Epoch 28/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7132 - loss: 0.6398 - val_accuracy: 0.5968 - val_loss: 0.9959
# Epoch 29/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7235 - loss: 0.6138 - val_accuracy: 0.5161 - val_loss: 1.0328
# Epoch 30/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7265 - loss: 0.6209 - val_accuracy: 0.5484 - val_loss: 1.1187
# Epoch 31/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7154 - loss: 0.6200 - val_accuracy: 0.5484 - val_loss: 1.0773
# Epoch 32/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7374 - loss: 0.5825 - val_accuracy: 0.5806 - val_loss: 1.0798
# Epoch 33/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7419 - loss: 0.5856 - val_accuracy: 0.6129 - val_loss: 1.2896
# Epoch 34/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 42ms/step - accuracy: 0.7465 - loss: 0.5865 - val_accuracy: 0.5968 - val_loss: 1.1312
# Epoch 35/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 51ms/step - accuracy: 0.7532 - loss: 0.5513 - val_accuracy: 0.5806 - val_loss: 1.1858
# Epoch 36/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 57ms/step - accuracy: 0.7631 - loss: 0.5304 - val_accuracy: 0.5968 - val_loss: 1.1304
# Epoch 37/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.7697 - loss: 0.5155 - val_accuracy: 0.5806 - val_loss: 1.4458
# Epoch 38/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.7504 - loss: 0.5304 - val_accuracy: 0.6613 - val_loss: 1.2485
# Epoch 39/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7732 - loss: 0.4824 - val_accuracy: 0.6290 - val_loss: 1.2160
# Epoch 40/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.7543 - loss: 0.5246 - val_accuracy: 0.6774 - val_loss: 1.4183
# Epoch 41/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7627 - loss: 0.5303 - val_accuracy: 0.5645 - val_loss: 1.3626
# Epoch 42/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8005 - loss: 0.4703 - val_accuracy: 0.5806 - val_loss: 1.5998
# Epoch 43/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 33ms/step - accuracy: 0.7880 - loss: 0.4752 - val_accuracy: 0.5645 - val_loss: 1.2733
# Epoch 44/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.7865 - loss: 0.4729 - val_accuracy: 0.6774 - val_loss: 1.3894
# Epoch 45/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8342 - loss: 0.4187 - val_accuracy: 0.6129 - val_loss: 1.4450
# Epoch 46/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8217 - loss: 0.4365 - val_accuracy: 0.5806 - val_loss: 1.4098
# Epoch 47/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8314 - loss: 0.4390 - val_accuracy: 0.5806 - val_loss: 1.5281
# Epoch 48/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8180 - loss: 0.4401 - val_accuracy: 0.6613 - val_loss: 1.5504
# Epoch 49/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8089 - loss: 0.4241 - val_accuracy: 0.6290 - val_loss: 1.4346
# Epoch 50/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 38ms/step - accuracy: 0.8242 - loss: 0.4167 - val_accuracy: 0.5968 - val_loss: 1.6012
# Epoch 51/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 37ms/step - accuracy: 0.8140 - loss: 0.4366 - val_accuracy: 0.6774 - val_loss: 1.6008
# Epoch 52/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8120 - loss: 0.4061 - val_accuracy: 0.6290 - val_loss: 1.6663
# Epoch 53/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8458 - loss: 0.3835 - val_accuracy: 0.6290 - val_loss: 1.5569
# Epoch 54/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8102 - loss: 0.4106 - val_accuracy: 0.5806 - val_loss: 1.7615
# Epoch 55/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8436 - loss: 0.3859 - val_accuracy: 0.6613 - val_loss: 1.6797
# Epoch 56/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 34ms/step - accuracy: 0.8417 - loss: 0.4047 - val_accuracy: 0.6452 - val_loss: 1.5658
# Epoch 57/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8809 - loss: 0.3450 - val_accuracy: 0.6935 - val_loss: 1.7806
# Epoch 58/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8491 - loss: 0.3839 - val_accuracy: 0.6290 - val_loss: 1.7544
# Epoch 59/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 35ms/step - accuracy: 0.8436 - loss: 0.3733 - val_accuracy: 0.6774 - val_loss: 1.6981
# Epoch 60/60
# 18/18 ━━━━━━━━━━━━━━━━━━━━ 1s 36ms/step - accuracy: 0.8649 - loss: 0.3185 - val_accuracy: 0.6774 - val_loss: 1.6030
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 320ms/step - accuracy: 0.5690 - loss: 1.2743
# Test loss: 1.2071
# Test accuracy: 0.5833
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 1s 231ms/step
